# %%
import pandas as pd

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_excel(r"C:\PROJECTS\Carrer_Path_Suggestion\data\career_dataset.xlsx")

# %%
print(df.head())
# Out:
#           Career                                              Skill
# 0  Web Developer  Conflict Resolution, Web Development, Web Perf...
# 1   Web Engineer  Attention to Detail, Code Review, Vite, Web De...
# 2  Web Architect  Presentation Skills, Communication, System Des...
# 3    Web Manager  TypeScript, Decision Making, HTML, Web Testing...
# 4    Web Analyst  HTML, System Design, Web Development, CSS, Pro...

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9604 entries, 0 to 9603
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Career  9604 non-null   str
#  1   Skill   9604 non-null   str
# dtypes: str(2)
# memory usage: 150.2 KB
# None

# %%
print(df.isnull().sum())
# Out:
# Career    0
# Skill     0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df["Skill"] = df["Skill"].str.lower()

# %%
X = df["Skill"]

# %%
Y = df["Career"]

# %%
vectorizer = TfidfVectorizer()

# %%
X_vectorized = vectorizer.fit_transform(X)

# %%
print(X_vectorized)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 216336 stored elements and shape (9604, 804)>
#   Coords	Values
#   (0, 136)	0.23546284884884955
#   (0, 587)	0.23252569503904078
#   (0, 784)	0.47704519414588764
#   (0, 190)	0.13848192847027654
#   (0, 497)	0.2330633075755342
#   (0, 477)	0.2727060569930793
#   (0, 764)	0.3153157117283771
#   (0, 142)	0.27937028153190385
#   (0, 282)	0.3153157117283771
#   (0, 313)	0.2396207191663045
#   (0, 703)	0.17300413880818238
#   (0, 183)	0.1587063509282134
#   (0, 360)	0.26460015791009883
#   (0, 155)	0.23581214241637835
#   (1, 784)	0.42480524023787025
#   (1, 190)	0.12331713978954569
#   (1, 313)	0.21338048977448382
#   (1, 703)	0.15405891443920608
#   (1, 183)	0.14132683938687282
#   (1, 360)	0.235624496436292
#   (1, 155)	0.2099889801626671
#   (1, 50)	0.21484172400392038
#   (1, 728)	0.1967177728298699
#   (1, 185)	0.21484172400392038
#   (1, 119)	0.21900159424446697
#   :	:
#   (9602, 583)	0.15518289938513205
#   (9602, 597)	0.18197755675466507
#   (9602, 204)	0.16269674428299202
#   (9602, 548)	0.12154202198230095
#   (9602, 585)	0.23791161319937845
#   (9602, 276)	0.23791161319937845
#   (9602, 435)	0.22964766057645442
#   (9602, 769)	0.21377390850874847
#   (9602, 677)	0.20930059059228903
#   (9602, 555)	0.30933409660098454
#   (9602, 529)	0.27710372961373964
#   (9602, 678)	0.48250052509245994
#   (9603, 340)	0.11748008232801632
#   (9603, 215)	0.11704541583262693
#   (9603, 345)	0.10509487649291036
#   (9603, 530)	0.13445592589279803
#   (9603, 452)	0.11528901876739653
#   (9603, 222)	0.20544981987195388
#   (9603, 264)	0.1450752081014023
#   (9603, 51)	0.21647693356147757
#   (9603, 690)	0.22564531778562438
#   (9603, 712)	0.27841206275944314
#   (9603, 89)	0.6789875406730544
#   (9603, 645)	0.3394937703365272
#   (9603, 419)	0.3394937703365272
